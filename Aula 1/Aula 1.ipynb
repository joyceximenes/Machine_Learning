# %% [markdown]
# # Aula 1 de Machine Learning - LEAD DELL

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

dados = pd.read_table('/content/drive/MyDrive/Machine Learning - LEAD DELL/Aula 1/fruit_data_with_colors.txt')
dados.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
dados.shape
# Out:
# (59, 7)

# %%
dados.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
dados.rename(columns = {
    'fruit_label' : 'Rótulo',
    'fruit_name' : 'Nome da fruta',
    'fruit_subtype' : 'Subtipo',
    'mass' : 'Peso',
    'width' : 'Largura',
    'height' : 'Altura',
    'color_score' : 'Intensidade das cores'
},inplace = True )

# %%
# analises estatisticas
dados.describe()
# Out:
#           Rótulo        Peso    Largura     Altura  Intensidade das cores
# count  59.000000   59.000000  59.000000  59.000000              59.000000
# mean    2.542373  163.118644   7.105085   7.693220               0.762881
# std     1.208048   55.018832   0.816938   1.361017               0.076857
# min     1.000000   76.000000   5.800000   4.000000               0.550000
# 25%     1.000000  140.000000   6.600000   7.200000               0.720000
# 50%     3.000000  158.000000   7.200000   7.600000               0.750000
# 75%     4.000000  177.000000   7.500000   8.200000               0.810000
# max     4.000000  362.000000   9.600000  10.500000               0.930000

# %%
dados.describe()['Peso']
# Out:
# count     59.000000
# mean     163.118644
# std       55.018832
# min       76.000000
# 25%      140.000000
# 50%      158.000000
# 75%      177.000000
# max      362.000000
# Name: Peso, dtype: float64

# %%
dados[['Peso', 'Nome da fruta']]

# %%
# intervalo
dados[5:10]
# Out:
#    Rótulo Nome da fruta   Subtipo  Peso  Largura  Altura  \
# 5       2      mandarin  mandarin    80      5.8     4.3
# 6       2      mandarin  mandarin    80      5.9     4.3
# 7       2      mandarin  mandarin    76      5.8     4.0
# 8       1         apple  braeburn   178      7.1     7.8
# 9       1         apple  braeburn   172      7.4     7.0
#
#    Intensidade das cores
# 5                   0.77
# 6                   0.81
# 7                   0.81
# 8                   0.92
# 9                   0.89

# %%
dados[['Nome da fruta', 'Peso']][2:5]
# Out:
#   Nome da fruta  Peso
# 2         apple   176
# 3      mandarin    86
# 4      mandarin    84

# %%
import matplotlib.pyplot as plt
freq = dados['Nome da fruta'].value_counts()  
freq
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# Name: Nome da fruta, dtype: int64

# %%
#determinando tipo de grafico
freq.plot(kind = 'bar')
plt.xticks(rotation = 360)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %%
# organizar por variavel
laranja = dados['Nome da fruta'] == 'orange'
dados[laranja].head()
# Out:
#     Rótulo Nome da fruta           Subtipo  Peso  Largura  Altura  \
# 24       3        orange     spanish_jumbo   342      9.0     9.4
# 25       3        orange     spanish_jumbo   356      9.2     9.2
# 26       3        orange     spanish_jumbo   362      9.6     9.2
# 27       3        orange  selected_seconds   204      7.5     9.2
# 28       3        orange  selected_seconds   140      6.7     7.1
#
#     Intensidade das cores
# 24                   0.75
# 25                   0.75
# 26                   0.74
# 27                   0.77
# 28                   0.72
