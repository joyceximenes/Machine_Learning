# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Leitura dos dados

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine Learning - LEAD DELL/Aula 8 (3.1 e 3.2)/Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# ### Verificar dados nulos

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# ### Informações estatísticas

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ### Gerando gráfico da idade versus score do cliente

# %%
plt.scatter(df['Age'], df['Spending Score (1-100)'], s=50)
plt.xlabel('Idade')
plt.ylabel('Score (1-100)')
plt.show()

# %% [markdown]
# ### Agora é sua vez de praticar

# %% [markdown]
# selecione os dados de 'Age' e 'Spending Score (1-100)' no dataframe para realizar o agrupamento com kmeans

# %%
# selecione no dataframe df as colunas Age e Spending Score (1-100)
X = df[['Age', 'Spending Score (1-100)']]
X.head()
# Out:
#    Age  Spending Score (1-100)
# 0   19                      39
# 1   21                      81
# 2   20                       6
# 3   23                      77
# 4   31                      40

# %% [markdown]
# ### Clusterizando com k = 5

# %%
# escreva aqui em baixo o código para fazer a clusterização
from sklearn.cluster import KMeans
modelo  = KMeans(n_clusters=5, init='k-means++')
y_kmeans = modelo.fit_predict(X)
print(y_kmeans)
# Out:
# [3 2 1 2 4 2 1 2 1 2 1 2 1 2 1 2 4 3 4 2 4 2 1 2 1 2 4 3 4 2 1 2 1 2 1 2 1
#  2 4 2 0 2 4 3 4 3 0 3 4 4 0 3 3 0 0 4 0 0 3 0 0 3 0 0 0 3 4 0 3 3 0 4 0 0
#  0 3 0 4 3 4 0 3 0 4 3 0 0 3 3 0 0 3 0 4 4 3 0 3 4 3 3 0 0 3 0 3 0 0 0 0 0
#  3 4 3 3 3 0 0 0 0 3 4 3 2 4 2 4 2 1 2 1 2 4 2 1 2 1 2 1 2 1 2 4 2 1 2 4 2
#  1 2 1 2 1 2 1 2 1 2 1 2 0 2 1 2 4 2 1 2 4 3 1 2 1 2 1 2 1 2 1 2 4 2 1 2 4
#  2 1 3 1 2 1 2 1 2 1 2 4 2 1 2]

# %% [markdown]
# ### Plot um gráfico com todos os grupos

# %%
# escreva aqui o código para plotar o gráfico
k_grupos = 5
cores = ['r', 'b', 'k', 'y', 'b']
for k in range(k_grupos):
  cluster = X[y_kmeans == k]
  plt.scatter(cluster['Age'], cluster['Spending Score (1-100)'], s = 100, c = cores[k], label = f'Clusters(k)')
plt.title('Grupos de clusters')
plt.xlabel('Idade')
plt.ylabel('Score')
plt.grid()
plt.legend()
plt.show()
