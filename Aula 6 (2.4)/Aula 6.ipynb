# %% [markdown]
# # ARVORES DE DECISÃO <p>
# Conjuntos de regra "se-então", utilizadas para classificação e regressão

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B = brilho

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# resultados: 0 e 0.47

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# quanto mais proximo de 0, melhor <p>
# o atributo que tiver o menor gini começa sendo a primeira divisão

# %% [markdown]
# # Implementação

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.datasets import load_boston, load_iris
from sklearn.model_selection import train_test_split

# %%
dt = DecisionTreeClassifier()

# %%
X,y = load_iris(return_X_y=True)
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
dt.fit(X_treino, y_treino)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_teste, y_teste)
# Out:
# 1.0

# %% [markdown]
# **regressão**

# %%
dt = DecisionTreeRegressor()

# %%
X,y = load_boston(return_X_y=True)
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
dt.fit(X_treino, y_treino)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(X_teste, y_teste)
# Out:
# 0.874024690137044

# %% [markdown]
# **ajustes para diminuir nós**

# %%
dt = DecisionTreeClassifier(max_depth=5)

# %%
X,y = load_iris(return_X_y=True)

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
dt.fit(X_treino, y_treino)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
dt.score(X_teste, y_teste)
# Out:
# 0.9473684210526315

# %% [markdown]
# quanto menor a arvore, maior a precisão

# %% [markdown]
# # Selecionando features

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer

# %%
dt = DecisionTreeClassifier()
X,y = load_breast_cancer(return_X_y=True)

# %%
dt.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
dt.feature_importances_ # medem a importancia dos atributos na construção do modelo
# Out:
# array([0.        , 0.01772124, 0.        , 0.        , 0.00701689,
#        0.00583135, 0.        , 0.04625107, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.00204521, 0.00100384,
#        0.00563858, 0.        , 0.        , 0.        , 0.        ,
#        0.69559352, 0.07728413, 0.        , 0.0110859 , 0.00738798,
#        0.        , 0.00872741, 0.10709688, 0.        , 0.007316  ])
